# %%
print("Welcome to the interactive personal Data Collector!""\n")

name = str(input("\nPlease enter your name : "))
age = int(input("\nPlease enter your age :"))
height = float(input("\nPlease enter your height in meters :"))
fnumber = int(input("\nPlease enter your favourite number :"))
 
print("\nThank you! here is the information we collected :-\n")
              
print("Name :", name ,"Type :",type(name),"Memory address : ",id(name))
print("Age :", age ,"Type :",type(age),"Memory address : ",id(age))
print("Height :", height ,"Type :",type(height),"Memory address : ",id(height))
print("Favourite Number :", fnumber ,"Type :",type(fnumber),"Memory address : ",id(fnumber))

birthy = (2026-age)

print("\nYour birth year is approximately :" , birthy ,"(based on your age of )", age )

print("\nThank you for using the Personal Data Collecter . Goodbye !\n")
# Out:
# Please enter your name :  Nitin
# Please enter your age : 20
# Please enter your height in meters : 13.5
# Please enter your favourite number : 4
# Thank you! here is the information we collected :
# Name : Nitin Type : <class 'str'> Memory address :  2036291437360
# Age : 20 Type : <class 'int'> Memory address :  140730179233288
# Height : 13.5 Type : <class 'float'> Memory address :  2036287493904
# Favourite Number : 4 Type : <class 'int'> Memory address :  140730179232776
# Your birth year is approximately : 2006 (based on your age of ) 20
# Thank you for using the Personal Data Collecter . Goodbye !
